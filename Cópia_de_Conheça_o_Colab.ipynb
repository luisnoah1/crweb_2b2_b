# %% [markdown]
# <a href="https://colab.research.google.com/github/luisnoah1/crweb_2b2_b/blob/main/C%C3%B3pia_de_Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exemplo de serviço

# %%
def soma(a, b):
  return (a+b)

# %%
soma(5, 55)
# Out:
# 60

# %% [markdown]
# # Sistema de Equações

# %%
from re import X
import math

def eq2grau(a, b, c):
  delta = b**2 - 4*a*c

  if(delta == 0):
    return 'equação sem solução'
  else:
  X1 = (-b + math.sqrt(delta)) / (2*a)
  x2 = (-b - math.sqrt(delta)) / (2*a)
  return x1, x2
# Out:
#   File "/tmp/ipykernel_2495/4162883550.py", line 9
#     x1 = (-b + math.sqrt(delta)) / (2*a)
#     ^
# IndentationError: expected an indented block after 'else' statement on line 8

# %%
print(eq2grau(2, -6, 9))
